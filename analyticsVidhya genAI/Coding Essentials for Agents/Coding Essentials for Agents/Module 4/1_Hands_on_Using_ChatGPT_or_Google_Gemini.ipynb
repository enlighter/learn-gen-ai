# %% [markdown]
# # Using ChatGPT or Google Gemini with Python for real-world tasks using thier APIs

# %%
# !pip install openai

# %% [markdown]
# ## Optional: Install Google Gemini
#
# Google Gemini API is free (till now). You can get a key [here](https://aistudio.google.com/app/apikey), just need to sign in with your google account. Gemini may not be available fully in EU.

# %%
# pip install -q -U google-generativeai

# %% [markdown]
# ## Load OpenAI API Credentials

# %%
from getpass import getpass

openai_key = getpass("Enter your OpenAI API Key: ")
# Out:
# Enter your OpenAI API Key:  ········

# %%
import openai
from IPython.display import HTML

openai.api_key = openai_key

# %% [markdown]
# ## Load Gemini API credentials
#
# Run this section only if you are using Google Gemini

# %%
from getpass import getpass

gemini_key = getpass("Enter your Gemini API Key: ")
# Out:
# Enter your Gemini API Key:  ········

# %%
import google.generativeai as genai

GOOGLE_API_KEY = gemini_key
genai.configure(api_key=GOOGLE_API_KEY)

# %% [markdown]
# ## Create ChatGPT and Google Gemini Chat Completion Access Function
#
# This function will use the [Chat Completion API](https://platform.openai.com/docs/api-reference/chat/create) to access ChatGPT for us and return responses
#
# We also add the capability to access the [Google Gemini API](https://ai.google.dev/tutorials/python_quickstart) if you want to use Gemini Pro instead of ChatGPT

# %%
def get_completion(prompt, model="gpt-4o"):
  if model == "gpt-4o":
    messages = [{"role": "user", "content": prompt}]
    response = openai.chat.completions.create(
        model=model,
        messages=messages,
        temperature=0.1, # degree of randomness of the model's output
    )
    return response.choices[0].message.content
      
  if model == 'gemini-2.5-pro':
    model = genai.GenerativeModel('gemini-2.5-pro')
    response = model.generate_content(prompt)
    return response.text
  else:
    return "LLM not configured! Please configure logic for specific model in get_completion()"

# %% [markdown]
# ## Exercise-1: Text Generation with both ChatGPT and Google Gemini
# - Get ChatGPT to generate text by asking it to write a story

# %%
response = get_completion("Write a short story about a college student.")
print(response)
# Out:
# Lena sat cross-legged on the worn-out couch in her tiny dorm room, surrounded by a fortress of textbooks and empty coffee cups. The soft glow of her laptop screen illuminated her face as she typed furiously, racing against the clock to finish her paper on Renaissance art. Outside, the autumn leaves danced in the crisp evening breeze, painting the campus in shades of gold and crimson.
#
# It was Lena's second year at Crestwood University, a small liberal arts college nestled in the heart of New England. She had come here with dreams of becoming an art historian, inspired by countless visits to museums with her grandmother, who had always encouraged her to see the world through the eyes of artists.
#
# Tonight, however, Lena felt anything but inspired. Her mind was a tangled mess of dates, names, and theories, and the pressure of looming deadlines weighed heavily on her shoulders. She glanced at the clock—11:47 PM. The paper was due at midnight.
#
# With a sigh, Lena leaned back and closed her eyes, trying to summon the words that had eluded her all evening. Her thoughts drifted to the painting she had chosen to analyze: Botticelli's "The Birth of Venus." She remembered standing in front of it during her summer trip to Florence, mesmerized by the ethereal beauty of the goddess emerging from the sea. The memory sparked a flicker of inspiration, and Lena's fingers danced across the keyboard once more.
#
# As the minutes ticked by, the words began to flow, weaving together a narrative that captured the essence of Botticelli's masterpiece. Lena wrote about the delicate interplay of light and shadow, the graceful curves of Venus's form, and the way the painting seemed to transcend time, inviting viewers into a world of myth and magic.
#
# At 11:59 PM, Lena hit "submit" and let out a breath she hadn't realized she'd been holding. Relief washed over her, mingled with a sense of accomplishment. She had done it.
#
# Exhausted but exhilarated, Lena stood up and stretched, her muscles protesting after hours of sitting. She walked over to the window and looked out at the campus below, where students were still bustling about, their laughter and chatter echoing through the night.
#
# In that moment, Lena felt a deep connection to the generations of students who had come before her, each of them navigating their own challenges and triumphs. She realized that college was not just about the grades or the papers, but about the journey of discovery and growth.
#
# With a newfound sense of purpose, Lena turned off her laptop and crawled into bed, pulling the covers up to her chin. As she drifted off to sleep, she dreamed of art and history, of stories yet to be told, and of the endless possibilities that awaited her in the days to come.

# %%
# with Gemini
response = get_completion("Write a short story about a college student.", model='gemini-2.5-pro')
print(response)
# Out:
# The third floor of the Oakhaven University library hummed with the low, electric thrum of a thousand unspoken anxieties. For Liam, the hum was a physical pressure behind his eyes. He stared at the same paragraph on the socio-political ramifications of the Peloponnesian War for what felt like an hour, the words swimming like black tadpoles in a sea of white.
#
# He was a ghost haunting a carrel, fueled by stale coffee and the fear of a C-minus. His roommate, a perpetually cheerful engineering major named Sam, was probably out at a party, navigating a world of red solo cups and easy laughter. Liam, meanwhile, was excavating the ruins of ancient Greece, and felt just as buried.
#
# Wasn’t this the dream? The acceptance letter, the tearful goodbye to his parents, the promise of becoming… something more. But three months in, the "more" felt like more exhaustion, more self-doubt, more of the gnawing suspicion that he was an imposter who had somehow slipped through admissions.
#
# He pushed his chair back with a grating screech that made a girl two carrels down look up, her expression a perfect blend of annoyance and pity. Cheeks burning, Liam gathered his worn-out backpack and fled the oppressive silence of the library.
#
# The night air was a shock—cool and crisp, smelling of damp leaves and distant rain. He pulled his hoodie tight and decided to take the long way back to his dorm, walking past the old brick-and-ivy humanities building. Lights were still on in a few of the professors’ offices, small golden squares against the dark facade. He imagined Dr. Alistair, his history professor, in there, a stooped figure with kind eyes and a passion for Athenian democracy so fierce it was almost contagious. For a moment, in Alistair’s lecture hall, Liam would feel it too—the thrill of understanding, of connecting the dots of the past. But then he’d get back to his room, face the textbook, and the magic would dissolve into a dense fog of names and dates.
#
# He kept walking, his footsteps echoing on the empty quad. He passed the student union, dark and silent now, where he’d tried and failed to make small talk during orientation. He passed the music building, from which a faint, melancholy piano melody drifted through an open window. Someone else was up late, speaking a language he understood better than Thucydides.
#
# It was in that moment, standing in the middle of the empty campus, that a strange sense of peace washed over him. He wasn't the only one. He wasn't the only one awake, the only one struggling, the only one chasing something that felt impossibly far away. The girl in the library, the professor in his office, the unseen pianist—they were all here, separate but together, each navigating their own late-night battles under the same indifferent stars.
#
# The campus wasn't a stage where he was failing his audition. It was just a place full of people. People trying. People tired. People who sometimes found a perfect, sad melody in the middle of the night.
#
# When Liam got back to his dorm room, the stack of books on his desk looked less like a mountain and more like a set of stairs. It was still daunting, still a climb. But for the first time in weeks, he felt like he could take the first step.
#
# He sat down, clicked on his desk lamp, and opened his textbook. The words were still just words, but the hum of anxiety had quieted. In its place was the soft, solitary sound of a page turning.

# %% [markdown]
# ## Exercise-2: Let's try out Zero Shot Prompting!
#
# - Let's get the model to answer the question about Generative AI

# %%
from IPython.display import display, Markdown

# %%
response = get_completion(prompt='Explain Generative AI in 2 bullet points')
display(Markdown(response))
# Out:
# - **Creation of New Content:** Generative AI refers to algorithms, often based on machine learning models like GANs (Generative Adversarial Networks) or transformers, that can generate new content such as text, images, music, or even code by learning patterns from existing data.
#
# - **Applications and Innovation:** It is widely used in various applications, including content creation, design, entertainment, and personalized experiences, driving innovation by automating creative processes and enabling the production of unique and diverse outputs.

# %%
# with Gemini
response = get_completion(prompt='Explain Generative AI in 2 bullet points',
                          model='gemini-2.5-pro')
display(Markdown(response))
# Out:
# Here is an explanation of Generative AI in two bullet points:
#
# *   It’s a type of artificial intelligence that **creates new, original content**—such as text, images, music, or code—rather than simply analyzing or categorizing existing data.
#
# *   It works by learning the patterns and styles from massive datasets and then uses that knowledge to **generate unique outputs based on a user's specific prompt** or instruction.

# %% [markdown]
# # Using Commercial LLMs with LangChain
#
# 1.   List item
# 2.   List item
#
#
#
# Here we will see briefly how you can use popular commercial LLM APIs with LangChain including
#
# - OpenAI GPT (Paid)
# - Google Gemini (Paid and Free)

# %% [markdown]
# ## Install Dependencies

# %%
# Updated LangChain to version 0.3.21 (March 18, 2025)
# Updated dependency packages:
# - langchain-openai==0.3.9
# - langchain-google-genai==2.1.0

# %%
# !pip install langchain==1.2.6 langchain-openai==1.1.7 langchain-google-genai==4.2.0 langchain-community==0.4.1
# !pip install langchain-openai==1.1.7 -q
# !pip install langchain-google-genai==4.2.0 -q
# !pip install langchain-community==0.4.1 -q
# Out:
# Requirement already satisfied: langchain==1.2.6 in /opt/miniconda3/envs/pg_python_ai/lib/python3.12/site-packages (1.2.6)
# Requirement already satisfied: langchain-openai==1.1.7 in /opt/miniconda3/envs/pg_python_ai/lib/python3.12/site-packages (1.1.7)
# Requirement already satisfied: langchain-google-genai==4.2.0 in /opt/miniconda3/envs/pg_python_ai/lib/python3.12/site-packages (4.2.0)
# Requirement already satisfied: langchain-community==0.4.1 in /opt/miniconda3/envs/pg_python_ai/lib/python3.12/site-packages (0.4.1)
# Requirement already satisfied: langchain-core<2.0.0,>=1.2.7 in /opt/miniconda3/envs/pg_python_ai/lib/python3.12/site-packages (from langchain==1.2.6) (1.2.7)
# Requirement already satisfied: langgraph<1.1.0,>=1.0.2 in /opt/miniconda3/envs/pg_python_ai/lib/python3.12/site-packages (from langchain==1.2.6) (1.0.6)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in /opt/miniconda3/envs/pg_python_ai/lib/python3.12/site-packages (from langchain==1.2.6) (2.12.4)
# Requirement already satisfied: openai<3.0.0,>=1.109.1 in /opt/miniconda3/envs/pg_python_ai/lib/python3.12/site-packages (from langchain-openai==1.1.7) (2.15.0)
# Requirement already satisfied: tiktoken<1.0.0,>=0.7.0 in /opt/miniconda3/envs/pg_python_ai/lib/python3.12/site-packages (from langchain-openai==1.1.7) (0.12.0)
# Requirement already satisfied: filetype<2.0.0,>=1.2.0 in /opt/miniconda3/envs/pg_python_ai/lib/python3.12/site-packages (from langchain-google-genai==4.2.0) (1.2.0)
# Requirement already satisfied: google-genai<2.0.0,>=1.56.0 in /opt/miniconda3/envs/pg_python_ai/lib/python3.12/site-packages (from langchain-google-genai==4.2.0) (1.60.0)
# Requirement already satisfied: langchain-classic<2.0.0,>=1.0.0 in /opt/miniconda3/envs/pg_python_ai/lib/python3.12/site-packages (from langchain-community==0.4.1) (1.0.1)
# Requirement already satisfied: SQLAlchemy<3.0.0,>=1.4.0 in /opt/miniconda3/envs/pg_python_ai/lib/python3.12/site-packages (from langchain-community==0.4.1) (2.0.45)
# Requirement already satisfied: requests<3.0.0,>=2.32.5 in /opt/miniconda3/envs/pg_python_ai/lib/python3.12/site-packages (from langchain-community==0.4.1) (2.32.5)
# Requirement already satisfied: PyYAML<7.0.0,>=5.3.0 in /opt/miniconda3/envs/pg_python_ai/lib/python3.12/site-packages (from langchain-community==0.4.1) (6.0.3)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.3 in /opt/miniconda3/envs/pg_python_ai/lib/python3.12/site-packages (from langchain-community==0.4.1) (3.13.3)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in /opt/miniconda3/envs/pg_python_ai/lib/python3.12/site-packages (from langchain-community==0.4.1) (9.1.2)
# Requirement already satisfied: dataclasses-json<0.7.0,>=0.6.7 in /opt/miniconda3/envs/pg_python_ai/lib/python3.12/site-packages (from langchain-community==0.4.1) (0.6.7)
# Requirement already satisfied: pydantic-settings<3.0.0,>=2.10.1 in /opt/miniconda3/envs/pg_python_ai/lib/python3.12/site-packages (from langchain-community==0.4.1) (2.12.0)
# Requirement already satisfied: langsmith<1.0.0,>=0.1.125 in /opt/miniconda3/envs/pg_python_ai/lib/python3.12/site-packages (from langchain-community==0.4.1) (0.6.4)
# Requirement already satisfied: httpx-sse<1.0.0,>=0.4.0 in /opt/miniconda3/envs/pg_python_ai/lib/python3.12/site-packages (from langchain-community==0.4.1) (0.4.3)
# Requirement already satisfied: numpy>=1.26.2 in /opt/miniconda3/envs/pg_python_ai/lib/python3.12/site-packages (from langchain-community==0.4.1) (2.3.5)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in /opt/miniconda3/envs/pg_python_ai/lib/python3.12/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community==0.4.1) (2.6.1)
# Requirement already satisfied: aiosignal>=1.4.0 in /opt/miniconda3/envs/pg_python_ai/lib/python3.12/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community==0.4.1) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in /opt/miniconda3/envs/pg_python_ai/lib/python3.12/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community==0.4.1) (25.4.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /opt/miniconda3/envs/pg_python_ai/lib/python3.12/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community==0.4.1) (1.8.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /opt/miniconda3/envs/pg_python_ai/lib/python3.12/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community==0.4.1) (6.7.0)
# Requirement already satisfied: propcache>=0.2.0 in /opt/miniconda3/envs/pg_python_ai/lib/python3.12/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community==0.4.1) (0.4.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /opt/miniconda3/envs/pg_python_ai/lib/python3.12/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community==0.4.1) (1.22.0)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in /opt/miniconda3/envs/pg_python_ai/lib/python3.12/site-packages (from dataclasses-json<0.7.0,>=0.6.7->langchain-community==0.4.1) (3.26.2)
# Requirement already satisfied: typing-inspect<1,>=0.4.0 in /opt/miniconda3/envs/pg_python_ai/lib/python3.12/site-packages (from dataclasses-json<0.7.0,>=0.6.7->langchain-community==0.4.1) (0.9.0)
# Requirement already satisfied: anyio<5.0.0,>=4.8.0 in /opt/miniconda3/envs/pg_python_ai/lib/python3.12/site-packages (from google-genai<2.0.0,>=1.56.0->langchain-google-genai==4.2.0) (4.10.0)
# Requirement already satisfied: google-auth<3.0.0,>=2.47.0 in /opt/miniconda3/envs/pg_python_ai/lib/python3.12/site-packages (from google-auth[requests]<3.0.0,>=2.47.0->google-genai<2.0.0,>=1.56.0->langchain-google-genai==4.2.0) (2.48.0rc0)
# Requirement already satisfied: httpx<1.0.0,>=0.28.1 in /opt/miniconda3/envs/pg_python_ai/lib/python3.12/site-packages (from google-genai<2.0.0,>=1.56.0->langchain-google-genai==4.2.0) (0.28.1)
# Requirement already satisfied: websockets<15.1.0,>=13.0.0 in /opt/miniconda3/envs/pg_python_ai/lib/python3.12/site-packages (from google-genai<2.0.0,>=1.56.0->langchain-google-genai==4.2.0) (15.0.1)
# Requirement already satisfied: typing-extensions<5.0.0,>=4.11.0 in /opt/miniconda3/envs/pg_python_ai/lib/python3.12/site-packages (from google-genai<2.0.0,>=1.56.0->langchain-google-genai==4.2.0) (4.15.0)
# Requirement already satisfied: distro<2,>=1.7.0 in /opt/miniconda3/envs/pg_python_ai/lib/python3.12/site-packages (from google-genai<2.0.0,>=1.56.0->langchain-google-genai==4.2.0) (1.9.0)
# Requirement already satisfied: sniffio in /opt/miniconda3/envs/pg_python_ai/lib/python3.12/site-packages (from google-genai<2.0.0,>=1.56.0->langchain-google-genai==4.2.0) (1.3.0)
# Requirement already satisfied: idna>=2.8 in /opt/miniconda3/envs/pg_python_ai/lib/python3.12/site-packages (from anyio<5.0.0,>=4.8.0->google-genai<2.0.0,>=1.56.0->langchain-google-genai==4.2.0) (3.11)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /opt/miniconda3/envs/pg_python_ai/lib/python3.12/site-packages (from google-auth<3.0.0,>=2.47.0->google-auth[requests]<3.0.0,>=2.47.0->google-genai<2.0.0,>=1.56.0->langchain-google-genai==4.2.0) (0.4.2)
# Requirement already satisfied: cryptography>=38.0.3 in /opt/miniconda3/envs/pg_python_ai/lib/python3.12/site-packages (from google-auth<3.0.0,>=2.47.0->google-auth[requests]<3.0.0,>=2.47.0->google-genai<2.0.0,>=1.56.0->langchain-google-genai==4.2.0) (46.0.3)
# Requirement already satisfied: rsa<5,>=3.1.4 in /opt/miniconda3/envs/pg_python_ai/lib/python3.12/site-packages (from google-auth<3.0.0,>=2.47.0->google-auth[requests]<3.0.0,>=2.47.0->google-genai<2.0.0,>=1.56.0->langchain-google-genai==4.2.0) (4.9.1)
# Requirement already satisfied: certifi in /opt/miniconda3/envs/pg_python_ai/lib/python3.12/site-packages (from httpx<1.0.0,>=0.28.1->google-genai<2.0.0,>=1.56.0->langchain-google-genai==4.2.0) (2026.1.4)
# Requirement already satisfied: httpcore==1.* in /opt/miniconda3/envs/pg_python_ai/lib/python3.12/site-packages (from httpx<1.0.0,>=0.28.1->google-genai<2.0.0,>=1.56.0->langchain-google-genai==4.2.0) (1.0.9)
# Requirement already satisfied: h11>=0.16 in /opt/miniconda3/envs/pg_python_ai/lib/python3.12/site-packages (from httpcore==1.*->httpx<1.0.0,>=0.28.1->google-genai<2.0.0,>=1.56.0->langchain-google-genai==4.2.0) (0.16.0)
# Requirement already satisfied: langchain-text-splitters<2.0.0,>=1.1.0 in /opt/miniconda3/envs/pg_python_ai/lib/python3.12/site-packages (from langchain-classic<2.0.0,>=1.0.0->langchain-community==0.4.1) (1.1.0)
# Requirement already satisfied: jsonpatch<2.0.0,>=1.33.0 in /opt/miniconda3/envs/pg_python_ai/lib/python3.12/site-packages (from langchain-core<2.0.0,>=1.2.7->langchain==1.2.6) (1.33)
# Requirement already satisfied: packaging<26.0.0,>=23.2.0 in /opt/miniconda3/envs/pg_python_ai/lib/python3.12/site-packages (from langchain-core<2.0.0,>=1.2.7->langchain==1.2.6) (25.0)
# Requirement already satisfied: uuid-utils<1.0,>=0.12.0 in /opt/miniconda3/envs/pg_python_ai/lib/python3.12/site-packages (from langchain-core<2.0.0,>=1.2.7->langchain==1.2.6) (0.14.0)
# Requirement already satisfied: jsonpointer>=1.9 in /opt/miniconda3/envs/pg_python_ai/lib/python3.12/site-packages (from jsonpatch<2.0.0,>=1.33.0->langchain-core<2.0.0,>=1.2.7->langchain==1.2.6) (3.0.0)
# Requirement already satisfied: langgraph-checkpoint<5.0.0,>=2.1.0 in /opt/miniconda3/envs/pg_python_ai/lib/python3.12/site-packages (from langgraph<1.1.0,>=1.0.2->langchain==1.2.6) (4.0.0)
# Requirement already satisfied: langgraph-prebuilt<1.1.0,>=1.0.2 in /opt/miniconda3/envs/pg_python_ai/lib/python3.12/site-packages (from langgraph<1.1.0,>=1.0.2->langchain==1.2.6) (1.0.6)
# Requirement already satisfied: langgraph-sdk<0.4.0,>=0.3.0 in /opt/miniconda3/envs/pg_python_ai/lib/python3.12/site-packages (from langgraph<1.1.0,>=1.0.2->langchain==1.2.6) (0.3.3)
# Requirement already satisfied: xxhash>=3.5.0 in /opt/miniconda3/envs/pg_python_ai/lib/python3.12/site-packages (from langgraph<1.1.0,>=1.0.2->langchain==1.2.6) (3.6.0)
# Requirement already satisfied: ormsgpack>=1.12.0 in /opt/miniconda3/envs/pg_python_ai/lib/python3.12/site-packages (from langgraph-checkpoint<5.0.0,>=2.1.0->langgraph<1.1.0,>=1.0.2->langchain==1.2.6) (1.12.2)
# Requirement already satisfied: orjson>=3.10.1 in /opt/miniconda3/envs/pg_python_ai/lib/python3.12/site-packages (from langgraph-sdk<0.4.0,>=0.3.0->langgraph<1.1.0,>=1.0.2->langchain==1.2.6) (3.11.5)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in /opt/miniconda3/envs/pg_python_ai/lib/python3.12/site-packages (from langsmith<1.0.0,>=0.1.125->langchain-community==0.4.1) (1.0.0)
# Requirement already satisfied: zstandard>=0.23.0 in /opt/miniconda3/envs/pg_python_ai/lib/python3.12/site-packages (from langsmith<1.0.0,>=0.1.125->langchain-community==0.4.1) (0.25.0)
# Requirement already satisfied: jiter<1,>=0.10.0 in /opt/miniconda3/envs/pg_python_ai/lib/python3.12/site-packages (from openai<3.0.0,>=1.109.1->langchain-openai==1.1.7) (0.12.0)
# Requirement already satisfied: tqdm>4 in /opt/miniconda3/envs/pg_python_ai/lib/python3.12/site-packages (from openai<3.0.0,>=1.109.1->langchain-openai==1.1.7) (4.67.1)
# Requirement already satisfied: annotated-types>=0.6.0 in /opt/miniconda3/envs/pg_python_ai/lib/python3.12/site-packages (from pydantic<3.0.0,>=2.7.4->langchain==1.2.6) (0.6.0)
# Requirement already satisfied: pydantic-core==2.41.5 in /opt/miniconda3/envs/pg_python_ai/lib/python3.12/site-packages (from pydantic<3.0.0,>=2.7.4->langchain==1.2.6) (2.41.5)
# Requirement already satisfied: typing-inspection>=0.4.2 in /opt/miniconda3/envs/pg_python_ai/lib/python3.12/site-packages (from pydantic<3.0.0,>=2.7.4->langchain==1.2.6) (0.4.2)
# Requirement already satisfied: python-dotenv>=0.21.0 in /opt/miniconda3/envs/pg_python_ai/lib/python3.12/site-packages (from pydantic-settings<3.0.0,>=2.10.1->langchain-community==0.4.1) (1.2.1)
# Requirement already satisfied: charset_normalizer<4,>=2 in /opt/miniconda3/envs/pg_python_ai/lib/python3.12/site-packages (from requests<3.0.0,>=2.32.5->langchain-community==0.4.1) (3.4.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/miniconda3/envs/pg_python_ai/lib/python3.12/site-packages (from requests<3.0.0,>=2.32.5->langchain-community==0.4.1) (2.5.0)
# Requirement already satisfied: pyasn1>=0.1.3 in /opt/miniconda3/envs/pg_python_ai/lib/python3.12/site-packages (from rsa<5,>=3.1.4->google-auth<3.0.0,>=2.47.0->google-auth[requests]<3.0.0,>=2.47.0->google-genai<2.0.0,>=1.56.0->langchain-google-genai==4.2.0) (0.6.2)
# Requirement already satisfied: regex>=2022.1.18 in /opt/miniconda3/envs/pg_python_ai/lib/python3.12/site-packages (from tiktoken<1.0.0,>=0.7.0->langchain-openai==1.1.7) (2025.11.3)
# Requirement already satisfied: mypy-extensions>=0.3.0 in /opt/miniconda3/envs/pg_python_ai/lib/python3.12/site-packages (from typing-inspect<1,>=0.4.0->dataclasses-json<0.7.0,>=0.6.7->langchain-community==0.4.1) (1.1.0)
# Requirement already satisfied: cffi>=2.0.0 in /opt/miniconda3/envs/pg_python_ai/lib/python3.12/site-packages (from cryptography>=38.0.3->google-auth<3.0.0,>=2.47.0->google-auth[requests]<3.0.0,>=2.47.0->google-genai<2.0.0,>=1.56.0->langchain-google-genai==4.2.0) (2.0.0)
# Requirement already satisfied: pycparser in /opt/miniconda3/envs/pg_python_ai/lib/python3.12/site-packages (from cffi>=2.0.0->cryptography>=38.0.3->google-auth<3.0.0,>=2.47.0->google-auth[requests]<3.0.0,>=2.47.0->google-genai<2.0.0,>=1.56.0->langchain-google-genai==4.2.0) (2.23)

# %% [markdown]
# # Enter API Keys
#
# Here you need to get API keys from the following websites based on your LLM preference:
#
# - Open AI API Key: Go [here](https://platform.openai.com/account/api-keys) and create a key, you need to setup an account and your own billing as this is a paid API. Unfortunately as per recent updates, OpenAI has phased out the free 5\$ credits. In order to use the API, you now have to pay in your own funds (min: 5\$).
#
# - Gemini API Key: Go [here](https://aistudio.google.com/app/u/0/apikey) and create a key, you just need a gmail account to sign in. Till now (mid-2024 so far), Gemini keys do not need billing as mentioned [here](https://ai.google.dev/pricing)

# %% [markdown]
# ## Load OpenAI API Credentials

# %%
from getpass import getpass

openai_key = getpass("Enter your OpenAI API Key: ")
# Out:
# Enter your OpenAI API Key:  ········

# %% [markdown]
# ## Configure Open AI Key in Environment

# %%
import os

os.environ['OPENAI_API_KEY'] = openai_key

# %% [markdown]
# ## Use OpenAI ChatGPT with LangChain

# %%
# Import path standardization - use updated import paths for cleaner code
from langchain_core.prompts import ChatPromptTemplate
from langchain_openai import ChatOpenAI
from langchain_google_genai import ChatGoogleGenerativeAI
# Parameter name change: 'model_name' is now 'model' in ChatOpenAI class
chatgpt = ChatOpenAI(model='gpt-4o-mini', temperature=0)

PROMPT = "Explain {topic} in 2 bullets"
prompt = ChatPromptTemplate.from_template(PROMPT)

chain = (
         prompt
           |
         chatgpt
)

response = chain.invoke({"topic": "AI"})
print(response.content)
# Out:
# - **Definition**: Artificial Intelligence (AI) refers to the simulation of human intelligence processes by machines, particularly computer systems, enabling them to perform tasks such as learning, reasoning, problem-solving, and understanding natural language.
#
# - **Applications**: AI is utilized across various fields, including healthcare (diagnosis and treatment recommendations), finance (fraud detection and algorithmic trading), autonomous vehicles (navigation and decision-making), and customer service (chatbots and virtual assistants).

# %% [markdown]
# ## Load Gemini API credentials
#
# Run this section only if you are using Google Gemini

# %%
from getpass import getpass

gemini_key = getpass("Enter your Gemini API Key: ")
# Out:
# Enter your Gemini API Key: ··········

# %% [markdown]
# ## Configure Gemini Key in Environment

# %%
import os

os.environ["GOOGLE_API_KEY"] = gemini_key

# %% [markdown]
# ## Use Gemini for Prompting

# %%
# Import path standardization - use updated import paths for cleaner code
from langchain_core.prompts import ChatPromptTemplate
from langchain_google_genai import ChatGoogleGenerativeAI
# Parameter name change: 'model_name' is now 'model' in ChatOpenAI class
gemini = ChatGoogleGenerativeAI(model="gemini-2.0-flash")

PROMPT = "Explain {topic} in 2 bullets"
prompt = ChatPromptTemplate.from_template(PROMPT)

chain = (
         prompt
           |
         gemini
)

response = chain.invoke({"topic": "AI"})
print(response.content)
# Out:
# *   **AI is the broad field of computer science focused on creating machines that can perform tasks that typically require human intelligence.** This includes things like learning, problem-solving, decision-making, and understanding natural language.
#
# *   **AI systems achieve this by using algorithms and data to mimic or simulate human cognitive functions.** These systems can be trained to recognize patterns, make predictions, and adapt to new situations without explicit programming for every possible scenario.
